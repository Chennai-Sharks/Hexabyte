# %%
import pandas as pd
import numpy as np
from pymongo import MongoClient
dataset=pd.read_csv("/content/drive/MyDrive/sih/recdata.csv",index_col=0) #Import Dataset or df from DB
print(dataset)
'''
1111100000
2222200000    
3333300000 are Animal Feed industries

4444400000  
5555500000     
6666600000 
7777700000 are Bio Ethanol plan industries
'''

# %%
import pandas as pd
import numpy as np
dataset=pd.read_csv("/content/drive/MyDrive/sih/recdata.csv",index_col=0) #Import Dataset or df from DB
dataset.fillna(0, inplace=True)
newdata=dataset.to_json(
    orient='index',
    index=True
)
print(newdata)
corrMatrix = dataset.corr(method='pearson')
# Product Id and Rating
user1_input = [("6",10),("7",8)]  #Pass the User's recently purchased Product_id and Rating - Must be a List of Tuples(if incase the user buying product for first time then pass the user's Applicable tags and give a good rating)
#recommendation(user1_input) #Calling the Recommendation fn

def recommendation(input):
    '''
    input = Must be a List of Tuples
    '''
    def get_similar(prod_name,rating):
        similar_ratings = corrMatrix[prod_name]*(rating-5)
        similar_ratings = similar_ratings.sort_values(ascending=False)    
        return similar_ratings

    def rec_algo(consumer):
        similar_products = pd.DataFrame()
        for prod_id,rating in consumer:
          similar_products = similar_products.append(get_similar(prod_id,rating),ignore_index = True)
        return similar_products

    consumer1 = rec_algo(input) #Call the Rec_algo fn
    ans = consumer1.sum().sort_values(ascending=False)
    #print(ans) #Descending order of Best Recommended Products
    suggested_products=[]
    not_suggested_products=[]
    for i in range(ans.size):
      if ans[i]>5:
        suggested_products.append(ans.index[i])
      else:
        not_suggested_products.append(ans.index[i])
    print(suggested_products,'\n',not_suggested_products) #Prints the User's Recommended Product_ids and NonRecommended Product_ids(worst case when there are no recommended products)

# %%
from pymongo import MongoClient
client = MongoClient("mongodb+srv://Nikhilesh:Dalesteyn08#@lewis.csy1lc4.mongodb.net/?retryWrites=true&w=majority")    
db = client.Lewis

# %%
prod_dataset=pd.read_csv("prod_data.tsv",sep='\t') #Import Dataset or df from DB
prod_dataset
# Out:
#     item_id  producer_id                 location             business  \
# 0         1   1111111111  [28.6138954,77.2090057]  restaurant_caterers
# 1         2   2222222222  [27.1752554,78.0098161]  restaurant_caterers
# 2         3   3333333333  [26.9154576,75.8189817]        juice_factory
# 3         4   4444444444   [19.0785451,72.878176]        juice_factory
# 4         5   5555555555   [18.521428,73.8544541]  farmers_agriculture
# 5         6   6666666666  [20.0112475,73.7902364]  restaurant_caterers
# 6         7   7777777777   [12.9767936,77.590082]        juice_factory
# 7         8   8888888888  [12.7328844,77.8309478]  restaurant_caterers
# 8         9   9999999999  [12.3051828,76.6553609]  farmers_agriculture
# 9        10   1000000000  [11.4126769,76.7030504]  restaurant_caterers
# 10       11   1100000000   [13.0836939,80.270186]        juice_factory
# 11       12   1200000000  [12.8796051,79.7042762]  farmers_agriculture
# ...

# %%
producers=[]
for i in range(1,16):
    producers.append("producer"+str(i))

# %%
producers
# Out:
# ['producer1',
#  'producer2',
#  'producer3',
#  'producer4',
#  'producer5',
#  'producer6',
#  'producer7',
#  'producer8',
#  'producer9',
#  'producer10',
#  'producer11',
#  'producer12',
#  'producer13',
#  'producer14',
#  'producer15']

# %%
prod_dataset['name']=producers

# %%
prod_dataset.columns
# Out:
# Index(['location', 'business', 'food_waste_title', 'applicable_tags',
#        'description', 'amount_processed', 'subscribed_qty', 'balance_qty',
#        'name'],
#       dtype='object')

# %%
user_data = prod_dataset[['location','business','name']]

# %%
# user_data['phone']=user_data.index
user_data['location']
# Out:
# 0     [28.6138954,77.2090057]
# 1     [27.1752554,78.0098161]
# 2     [26.9154576,75.8189817]
# 3      [19.0785451,72.878176]
# 4      [18.521428,73.8544541]
# 5     [20.0112475,73.7902364]
# 6      [12.9767936,77.590082]
# 7     [12.7328844,77.8309478]
# 8     [12.3051828,76.6553609]
# 9     [11.4126769,76.7030504]
# 10     [13.0836939,80.270186]
# 11    [12.8796051,79.7042762]
# 12    [11.9340568,79.8306447]
# 13      [8.4882267,76.947551]
# 14     [9.3181018,76.3809006]
# Name: location, dtype: object

# %%
user_data.to_json('user_data.json',orient='records')

# %%
user_data['location']=list(user_data['location'])
# Out:
# C:\Users\Naveen Sriram\AppData\Local\Temp\ipykernel_7568\2080427627.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_data['location']=list(user_data['location'])

# %%
user_data['phone']=prod_dataset['producer_id']
# Out:
# C:\Users\Naveen Sriram\AppData\Local\Temp\ipykernel_7568\2589257109.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_data['phone']=prod_dataset['producer_id']

# %%
user_data
# Out:
#                    location             business        name       phone
# 0   [28.6138954,77.2090057]  restaurant_caterers   producer1  1111111111
# 1   [27.1752554,78.0098161]  restaurant_caterers   producer2  2222222222
# 2   [26.9154576,75.8189817]        juice_factory   producer3  3333333333
# 3    [19.0785451,72.878176]        juice_factory   producer4  4444444444
# 4    [18.521428,73.8544541]  farmers_agriculture   producer5  5555555555
# 5   [20.0112475,73.7902364]  restaurant_caterers   producer6  6666666666
# 6    [12.9767936,77.590082]        juice_factory   producer7  7777777777
# 7   [12.7328844,77.8309478]  restaurant_caterers   producer8  8888888888
# 8   [12.3051828,76.6553609]  farmers_agriculture   producer9  9999999999
# 9   [11.4126769,76.7030504]  restaurant_caterers  producer10  1000000000
# 10   [13.0836939,80.270186]        juice_factory  producer11  1100000000
# 11  [12.8796051,79.7042762]  farmers_agriculture  producer12  1200000000
# ...

# %%
user_data['location'].to_json

# %%
for i in db.metadata.find({},{'_id':True,'name':True}):
    print(i)
# Out:
# {'_id': ObjectId('62fd59c34f9c0349a5949051'), 'name': 'Nivaan'}
# {'_id': ObjectId('62fe1d972d17efbca98209b7'), 'name': 'Nivaan-2.0'}
# {'_id': ObjectId('62fe66462d1379979a85b428'), 'name': 'Nivaan'}
# {'_id': ObjectId('62ff6296cb774acb24f4bf93'), 'name': 'nivaan 3.0'}
# {'_id': ObjectId('62ff818724c8cc62c4b5a592'), 'name': 'Nivaan'}
# {'_id': ObjectId('63011add044fac9c555ab9eb'), 'name': 'Nivaan'}
# {'_id': ObjectId('6301203e49aa50692ff4ca40'), 'name': 'Search_test'}
# {'_id': ObjectId('6301206649aa50692ff4ca41'), 'name': 'Search_test_1'}
# {'_id': ObjectId('6305d8a23aabb8b65fa83a7a'), 'name': 'Janakasudha'}
# {'_id': ObjectId('6306569246fca77cacb91c26'), 'name': 'producer1'}
# {'_id': ObjectId('6306569246fca77cacb91c27'), 'name': 'producer2'}
# {'_id': ObjectId('6306569246fca77cacb91c28'), 'name': 'producer3'}
# {'_id': ObjectId('6306569246fca77cacb91c29'), 'name': 'producer4'}
# {'_id': ObjectId('6306569246fca77cacb91c2a'), 'name': 'producer5'}
# ...

# %%
import json
f = open("mydata.json")
data=json.load(f)
print(data)
# Out:
# [{'customer_id': '1111100000', 'item_id': {'$oid': '6306569246fca77cacb91c26'}, 'rating': 2.0}, {'customer_id': '1111100000', 'item_id': {'$oid': '6306569246fca77cacb91c27'}, 'rating': 2.0}, {'customer_id': '1111100000', 'item_id': {'$oid': '6306569246fca77cacb91c28'}, 'rating': 8.0}, {'customer_id': '1111100000', 'item_id': {'$oid': '6306569246fca77cacb91c29'}, 'rating': 0.0}, {'customer_id': '1111100000', 'item_id': {'$oid': '6306569246fca77cacb91c2a'}, 'rating': 10.0}, {'customer_id': '1111100000', 'item_id': {'$oid': '6306569246fca77cacb91c2b'}, 'rating': 3.0}, {'customer_id': '1111100000', 'item_id': {'$oid': '6306569246fca77cacb91c2c'}, 'rating': 0.0}, {'customer_id': '1111100000', 'item_id': {'$oid': '6306569246fca77cacb91c2d'}, 'rating': 0.0}, {'customer_id': '1111100000', 'item_id': {'$oid': '6306569246fca77cacb91c2e'}, 'rating': 0.0}, {'customer_id': '1111100000', 'item_id': {'$oid': '6306569246fca77cacb91c2f'}, 'rating': 1.0}, {'customer_id': '1111100000', 'item_id': {'$oi
# ...

# %%
db.Ratings.insert_many(data)

# %%
df
# Out:
#                           _id customer_id  \
# 0    63065f1d1cf985b369eb8b4c  1111100000
# 1    63065f1d1cf985b369eb8b4d  1111100000
# 2    63065f1d1cf985b369eb8b4e  1111100000
# 3    63065f1d1cf985b369eb8b4f  1111100000
# 4    63065f1d1cf985b369eb8b50  1111100000
# ..                        ...         ...
# 100  63065f1d1cf985b369eb8bb0  7777700000
# 101  63065f1d1cf985b369eb8bb1  7777700000
# 102  63065f1d1cf985b369eb8bb2  7777700000
# 103  63065f1d1cf985b369eb8bb3  7777700000
# 104  63065f1d1cf985b369eb8bb4  7777700000
#
#                                   item_id  rating                      item
# 0    {'$oid': '6306569246fca77cacb91c26'}     2.0  6306569246fca77cacb91c26
# 1    {'$oid': '6306569246fca77cacb91c27'}     2.0  6306569246fca77cacb91c27
# 2    {'$oid': '6306569246fca77cacb91c28'}     8.0  6306569246fca77cacb91c28
# 3    {'$oid': '6306569246fca77cacb91c29'}     0.0  6306569246fca77cacb91c29
# ...

# %%
data = db.Ratings.find({})
df = pd.DataFrame.from_records(data)
df['item'] = df['item_id'].map(lambda item: item['$oid'])
dataset = df[['customer_id','item','rating']].pivot(index='customer_id' ,columns='item',values='rating')
# Out:
#                          item  rating
# 0    6306569246fca77cacb91c26     2.0
# 1    6306569246fca77cacb91c27     2.0
# 2    6306569246fca77cacb91c28     8.0
# 3    6306569246fca77cacb91c29     0.0
# 4    6306569246fca77cacb91c2a    10.0
# ..                        ...     ...
# 100  6306569246fca77cacb91c30     1.0
# 101  6306569246fca77cacb91c31     0.0
# 102  6306569246fca77cacb91c32     1.0
# 103  6306569246fca77cacb91c33     2.0
# 104  6306569246fca77cacb91c34     2.0
#
# [105 rows x 2 columns]

# %%
dataset = df[['customer_id','item','rating']].pivot(index='customer_id' ,columns='item',values='rating')

# %%
def recommendation(input):
    '''
    input = Must be a List of Tuples
    '''
    def get_similar(prod_name,rating):
        similar_ratings = corrMatrix[prod_name]*(rating-5)
        similar_ratings = similar_ratings.sort_values(ascending=False)    
        return similar_ratings

    def rec_algo(consumer):
        similar_products = pd.DataFrame()
        for prod_id,rating in consumer:
          similar_products = similar_products.append(get_similar(prod_id,rating),ignore_index = True)
        return similar_products

    consumer1 = rec_algo(input) #Call the Rec_algo fn
    ans = consumer1.sum().sort_values(ascending=False)
    #print(ans) #Descending order of Best Recommended Products
    suggested_products=[]
    not_suggested_products=[]
    for i in range(ans.size):
      if ans[i]>5:
        suggested_products.append(ans.index[i])
      else:
        not_suggested_products.append(ans.index[i])
    print(suggested_products,'\n',not_suggested_products) #Prints the User's Recommended Product_ids and NonRecommended Product_ids(worst case when there are no recommended products)

# %%
#copy from here on 
data = db.Ratings.find({})
df = pd.DataFrame.from_records(data)
df['item'] = df['item_id'].map(lambda item: item['$oid'])
dataset = df[['customer_id','item','rating']].pivot(index='customer_id' ,columns='item',values='rating')
corrMatrix = dataset.corr(method='pearson')

# %%
user1_input = [("6306569246fca77cacb91c2b",10),("6306569246fca77cacb91c2c",8)]
recommendation(user1_input)
# Out:
# ['6306569246fca77cacb91c2b', '6306569246fca77cacb91c31', '6306569246fca77cacb91c2c', '6306569246fca77cacb91c2e', '6306569246fca77cacb91c2f']
#  ['6306569246fca77cacb91c2d', '6306569246fca77cacb91c30', '6306569246fca77cacb91c26', '6306569246fca77cacb91c27', '6306569246fca77cacb91c33', '6306569246fca77cacb91c2a', '6306569246fca77cacb91c29', '6306569246fca77cacb91c34', '6306569246fca77cacb91c32', '6306569246fca77cacb91c28']
# C:\Users\Naveen Sriram\AppData\Local\Temp\ipykernel_7568\584796827.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   similar_products = similar_products.append(get_similar(prod_id,rating),ignore_index = True)
# C:\Users\Naveen Sriram\AppData\Local\Temp\ipykernel_7568\584796827.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
from pymongo import GEO2D
db.Items.create_index([("location", GEO2D)])
# Out:
# 'location_2d'

# %%
arr=[]
for i in db.Items.find({},{'_id':True}).sort('_id',1):
    print(i.get('_id'))
# Out:
# 630759c346fca77cacb91d54
# 630759c346fca77cacb91d55
# 630759c346fca77cacb91d56
# 630759c346fca77cacb91d57
# 630759c346fca77cacb91d58
# 630759c346fca77cacb91d59
# 630759c346fca77cacb91d5a
# 630759c346fca77cacb91d5b
# 630759c346fca77cacb91d5c
# 630759c346fca77cacb91d5d
# 630759c346fca77cacb91d5e
# 630759c346fca77cacb91d5f
# 630759c346fca77cacb91d60
# 630759c346fca77cacb91d61
# 630759c346fca77cacb91d62

# %%
len(arr)
# Out:
# 15

# %%
arr=['630759c346fca77cacb91d54',
'630759c346fca77cacb91d55',
'630759c346fca77cacb91d56',
'630759c346fca77cacb91d57',
'630759c346fca77cacb91d58',
'630759c346fca77cacb91d59',
'630759c346fca77cacb91d5a',
'630759c346fca77cacb91d5b',
'630759c346fca77cacb91d5c',
'630759c346fca77cacb91d5d',
'630759c346fca77cacb91d5e',
'630759c346fca77cacb91d5f',
'630759c346fca77cacb91d60',
'630759c346fca77cacb91d61',
'630759c346fca77cacb91d62']

# %%
import json
f = open("mydata (2).json")
data=json.load(f)
print(data)
# Out:
# [{'user_id': '1111100000', 'item_id': '1', 'rating': 2.0}, {'user_id': '1111100000', 'item_id': '2', 'rating': 2.0}, {'user_id': '1111100000', 'item_id': '3', 'rating': 8.0}, {'user_id': '1111100000', 'item_id': '4', 'rating': 0.0}, {'user_id': '1111100000', 'item_id': '5', 'rating': 10.0}, {'user_id': '1111100000', 'item_id': '6', 'rating': 3.0}, {'user_id': '1111100000', 'item_id': '7', 'rating': 0.0}, {'user_id': '1111100000', 'item_id': '8', 'rating': 0.0}, {'user_id': '1111100000', 'item_id': '9', 'rating': 0.0}, {'user_id': '1111100000', 'item_id': '10', 'rating': 1.0}, {'user_id': '1111100000', 'item_id': '11', 'rating': 0.0}, {'user_id': '1111100000', 'item_id': '12', 'rating': 0.0}, {'user_id': '1111100000', 'item_id': '13', 'rating': 9.0}, {'user_id': '1111100000', 'item_id': '14', 'rating': 0.0}, {'user_id': '1111100000', 'item_id': '15', 'rating': 9.0}, {'user_id': '2222200000', 'item_id': '1', 'rating': 2.0}, {'user_id': '2222200000', 'item_id': '2', 'rating': 1.0}, {'us
# ...

# %%
results = db.Items.find({},{'_id':True}).sort('_id',1)
for i in range(1,16):
    for item in data:
        if item['item_id']==str(i):
            item['item_id'] = {"$oid":arr[i-1]}

# %%
data
# Out:
# [{'user_id': '1111100000',
#   'item_id': {'$oid': '630759c346fca77cacb91d54'},
#   'rating': 2.0},
#  {'user_id': '1111100000',
#   'item_id': {'$oid': '630759c346fca77cacb91d55'},
#   'rating': 2.0},
#  {'user_id': '1111100000',
#   'item_id': {'$oid': '630759c346fca77cacb91d56'},
#   'rating': 8.0},
#  {'user_id': '1111100000',
#   'item_id': {'$oid': '630759c346fca77cacb91d57'},
#   'rating': 0.0},
#  {'user_id': '1111100000',
#   'item_id': {'$oid': '630759c346fca77cacb91d58'},
#   'rating': 10.0},
#  {'user_id': '1111100000',
#   'item_id': {'$oid': '630759c346fca77cacb91d59'},
#   'rating': 3.0},
#  {'user_id': '1111100000',
#   'item_id': {'$oid': '630759c346fca77cacb91d5a'},
#   'rating': 0.0},
#  {'user_id': '1111100000',
#   'item_id': {'$oid': '630759c346fca77cacb91d5b'},
#   'rating': 0.0},
#  {'user_id': '1111100000',
#   'item_id': {'$oid': '630759c346fca77cacb91d5c'},
#   'rating': 0.0},
#  {'user_id': '1111100000',
# ...

# %%
db.Ratings.insert_many(data)

# %%
db.Orders.update({"one_time":False},{'$set':{"item_id":{"$oid":
"630759c346fca77cacb91d54"}}})
# Out:
# C:\Users\Naveen Sriram\AppData\Local\Temp\ipykernel_43412\206822211.py:1: DeprecationWarning: update is deprecated. Use replace_one, update_one or update_many instead.
#   db.Orders.update({"one_time":False},{'$set':{"item_id":{"$oid":
# {'n': 1,
#  'electionId': ObjectId('7fffffff000000000000006a'),
#  'opTime': {'ts': Timestamp(1661449283, 5), 't': 106},
#  'nModified': 1,
#  'ok': 1.0,
#  '$clusterTime': {'clusterTime': Timestamp(1661449283, 5),
#   'signature': {'hash': b'\xa6\x90x\x10\xf1\xb7\x1fk\x95L%\xdf\x8bvT\xd1\xaew+6',
#    'keyId': 7082038713303171073}},
#  'operationTime': Timestamp(1661449283, 5),
#  'updatedExisting': True}

# %%
from bson import ObjectId

# %%
for i in db.Ratings.find({"item_id.$oid":"630759c346fca77cacb91d55"}):
    print(i)
# Out:
# {'_id': ObjectId('630769f07c523e68afd22155'), 'user_id': '1111100000', 'item_id': {'$oid': '630759c346fca77cacb91d55'}, 'rating': 2.0}
# {'_id': ObjectId('630769f07c523e68afd22164'), 'user_id': '2222200000', 'item_id': {'$oid': '630759c346fca77cacb91d55'}, 'rating': 1.0}
# {'_id': ObjectId('630769f07c523e68afd22173'), 'user_id': '3333300000', 'item_id': {'$oid': '630759c346fca77cacb91d55'}, 'rating': 2.0}
# {'_id': ObjectId('630769f07c523e68afd22182'), 'user_id': '4444400000', 'item_id': {'$oid': '630759c346fca77cacb91d55'}, 'rating': 0.0}
# {'_id': ObjectId('630769f07c523e68afd22191'), 'user_id': '5555500000', 'item_id': {'$oid': '630759c346fca77cacb91d55'}, 'rating': 3.0}
# {'_id': ObjectId('630769f07c523e68afd221a0'), 'user_id': '6666600000', 'item_id': {'$oid': '630759c346fca77cacb91d55'}, 'rating': 2.0}
# {'_id': ObjectId('630769f07c523e68afd221af'), 'user_id': '7777700000', 'item_id': {'$oid': '630759c346fca77cacb91d55'}, 'rating': 2.0}
